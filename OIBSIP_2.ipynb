# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiRupan/OIBSIP-DataScience-Intern-Tasks/blob/main/OIBSIP_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #OASIS INFOBYTE
# ##Data Science Internship
# Name:Thirunahari Sai Rupan
#
# TASK-2:CAR PRICE PREDICTION WITH MACHINE LEARNING

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder

# %%
car_df = pd.read_csv('car data.csv')
car_df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %% [markdown]
# ##Exploratory Data Analysis

# %%
car_df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car_df.duplicated().sum()
# Out:
# 2

# %%
car_df.drop_duplicates(inplace = True)

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Year           299 non-null    int64
#  2   Selling_Price  299 non-null    float64
#  3   Present_Price  299 non-null    float64
#  4   Driven_kms     299 non-null    int64
#  5   Fuel_Type      299 non-null    object
#  6   Selling_type   299 non-null    object
#  7   Transmission   299 non-null    object
#  8   Owner          299 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 23.4+ KB

# %%
car_df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   299.000000     299.000000     299.000000     299.000000  299.000000
# mean   2013.615385       4.589632       7.541037   36916.752508    0.043478
# std       2.896868       4.984240       8.566332   39015.170352    0.248720
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.850000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.510000       6.100000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.840000   48883.500000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car_df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
plt.figure(figsize = (15,8))

for i,z in enumerate(['Selling_Price', 'Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.histplot(data =car_df, x = z,kde = True,hue = 'Transmission')
plt.show()

# %%
plt.figure(figsize = (15,10))
for i,col in enumerate(['Selling_Price','Present_Price', 'Driven_kms']):
    for j,col2 in enumerate(['Transmission', 'Owner']):
        plt.subplot(3,2,i * 2 + j + 1)
        sns.boxplot(data =car_df, y = col2,x = col,orient = 'h')

# %%
def outliers(col):
    per25 = car_df[col].quantile(0.25)
    per75 = car_df[col].quantile(0.75)
    IQR = per75 - per25               #Inter Quartile Range
    UL = per75 + 1.5 * IQR            #Upper Limit
    LL = per25 - 1.5 * IQR            #Lower Limit
#     print("IQR - ",IQR)
#     print("Upper Limit & Lower Limit - ",UL,LL)
#     print(df[df[col]>UL],'\n',df[df[col]<LL])
    return car_df[col]>UL

# %%
car_df = car_df.drop(car_df[outliers('Selling_Price')].index)

# %%
car_df = car_df.drop(car_df[outliers('Present_Price')].index)
car_df = car_df.drop(car_df[outliers('Driven_kms')].index)

# %%
car_df['Transmission'].value_counts()
# Out:
# Manual       253
# Automatic     22
# Name: Transmission, dtype: int64

# %%
sns.pairplot(data =car_df , hue = 'Transmission')

# %%
Labelencode = LabelEncoder()

# %%
cat_vars = car_df.select_dtypes('O').columns
for i in cat_vars:

    car_df[i] = Labelencode.fit_transform(car_df[i])
car_df.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0        86  2014           3.35           5.59       27000          2
# 1        89  2013           4.75           9.54       43000          1
# 2        66  2017           7.25           9.85        6900          2
# 3        92  2011           2.85           4.15        5200          2
# 4        88  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             1      0
# 1             0             1      0
# 2             0             1      0
# 3             0             1      0
# 4             0             1      0

# %%
cor =car_df.corr()
plt.figure(figsize=(10,4))
mask = np.triu(np.ones_like(cor, dtype=bool))
np.fill_diagonal(mask, False)
sns.heatmap(cor, annot=True, mask=mask, vmin=-1, vmax=2,linewidths=0.2, cmap='plasma')
plt.title("Correlation Matrix", fontsize=15)
plt.show()

# %%
car_df.drop(columns = 'Selling_type',axis = 1,inplace=True)

# %%
car_df.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0        86  2014           3.35           5.59       27000          2
# 1        89  2013           4.75           9.54       43000          1
# 2        66  2017           7.25           9.85        6900          2
# 3        92  2011           2.85           4.15        5200          2
# 4        88  2014           4.60           6.87       42450          1
#
#    Transmission  Owner
# 0             1      0
# 1             1      0
# 2             1      0
# 3             1      0
# 4             1      0

# %% [markdown]
# #Model Building

# %%
Y = car_df['Selling_Price']
X = car_df.drop(columns = 'Selling_Price')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(X,Y,test_size = 0.2, random_state = 23)

# %%
scale = MinMaxScaler()
Xtrain = scale.fit_transform(Xtrain)

# %%
Xtest = scale.transform(Xtest)

# %%
kf = KFold(n_splits=15, shuffle=True, random_state=42)
param_grid = {
    'n_estimators': [50,100, 200, 300],
    'max_depth': [None,5, 10, 20],
    'min_samples_split': [2,3, 6, 10]
}

grid_search = GridSearchCV(estimator=RandomForestRegressor(random_state=42),
                           param_grid=param_grid,
                           scoring='neg_root_mean_squared_error',
                           cv=kf,
                           n_jobs=-1)

# %%
grid_search.fit(Xtrain,ytrain)
# Out:
# GridSearchCV(cv=KFold(n_splits=15, random_state=42, shuffle=True),
#              estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10, 20],
#                          'min_samples_split': [2, 3, 6, 10],
#                          'n_estimators': [50, 100, 200, 300]},
#              scoring='neg_root_mean_squared_error')

# %%
grid_search.fit(Xtrain,ytrain)
# Out:
# GridSearchCV(cv=KFold(n_splits=15, random_state=42, shuffle=True),
#              estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10, 20],
#                          'min_samples_split': [2, 3, 6, 10],
#                          'n_estimators': [50, 100, 200, 300]},
#              scoring='neg_root_mean_squared_error')

# %%
print('We can get accuracy of',grid_search.best_score_,'using',grid_search.best_params_)
# Out:
# We can get accuracy of -0.6829635110545148 using {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 300}

# %%
model = LinearRegression()
model.fit(Xtrain, ytrain)
ypred = model.predict(Xtest)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 1.26
# R-squared (R2): 0.87

# %%
rf_model = RandomForestRegressor(random_state=17)
rf_model.fit(Xtrain, ytrain)
rf_Y_pred = rf_model.predict(Xtest)
rf_mse = mean_squared_error(ytest, rf_Y_pred)
rf_r2 = r2_score(ytest, rf_Y_pred)
print(f"Random Forest Mean Squared Error (MSE): {rf_mse:.2f}")
print(f"Random Forest R-squared (R2): {rf_r2:.2f}")
# Out:
# Random Forest Mean Squared Error (MSE): 0.36
# Random Forest R-squared (R2): 0.96

# %%
plt.figure(figsize=(15, 6))
plt.scatter(ytest, ypred, alpha=0.5)
plt.xlabel('Actual Selling Price')
plt.ylabel('Predicted Selling Price')
plt.title('Actual vs. Predicted Selling Prices (Linear Regression)')
plt.show()
